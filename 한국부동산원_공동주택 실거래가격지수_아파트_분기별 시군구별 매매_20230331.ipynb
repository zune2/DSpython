# %%
import pandas as pd
# Out:
# /home/mjpark/anaconda3/lib/python3.7/site-packages/pandas/compat/_optional.py:138: UserWarning: Pandas requires version '2.7.0' or newer of 'numexpr' (version '2.6.9' currently installed).
#   warnings.warn(msg, UserWarning)

# %%
df = pd.read_csv("data/한국부동산원_공동주택 실거래가격지수_아파트_분기별 시군구별 매매_20230331.csv", encoding="euc-kr")
df
# Out:
#          지역  2006년 01분기  2006년 02분기  2006년 03분기  2006년 04분기  2007년 01분기  \
# 0    서울 종로구        58.3        57.1        59.8        65.5        70.1
# 1     서울 중구        60.1        61.0        62.6        67.0        71.0
# 2    서울 용산구        57.8        60.1        64.7        70.5        71.8
# 3    서울 성동구        56.9        59.1        61.5        66.8        73.4
# 4    서울 광진구        57.8        60.3        63.5        72.5        76.7
# ..      ...         ...         ...         ...         ...         ...
# 109  경기 화성시        74.8        74.7        78.1        86.6        94.1
# 110  경기 광주시        74.7        79.1        84.5        96.0       111.2
# 111  경기 양주시        56.5        57.6        58.9        62.4        67.3
# 112  경기 포천시        51.9        54.8        52.4        55.4        59.0
# 113  경기 여주시        51.4        52.0        54.6        56.5        58.3
#
#      2007년 02분기  2007년 03분기  2007년 04분기  2008년 01분기  ...  2020년 04분기  \
# ...

# %%
# https://stackoverflow.com/questions/26147180/convert-row-to-column-header-for-pandas-dataframe
df_T = df.transpose()
df_T.columns = df_T.iloc[0] # 맨 윗줄을 컬럼명으로 지정
df_T = df_T.drop(df_T.index[0])    # 맨 윗줄을 지움
df_T
# Out:
# 지역         서울 종로구  서울 중구 서울 용산구 서울 성동구 서울 광진구 서울 동대문구 서울 중랑구 서울 성북구 서울 강북구  \
# 2006년 01분기   58.3   60.1   57.8   56.9   57.8    59.1   55.7   60.1   56.3
# 2006년 02분기   57.1   61.0   60.1   59.1   60.3    59.3   56.3   60.9   56.3
# 2006년 03분기   59.8   62.6   64.7   61.5   63.5    60.7   57.1   62.5   57.3
# 2006년 04분기   65.5   67.0   70.5   66.8   72.5    64.5   62.4   67.5   63.2
# 2007년 01분기   70.1   71.0   71.8   73.4   76.7    71.0   68.2   74.0   70.2
# ...           ...    ...    ...    ...    ...     ...    ...    ...    ...
# 2022년 01분기  158.5  164.3  191.4  200.2  183.6   183.1  180.4  188.8  177.2
# 2022년 02분기  158.6  165.3  192.2  201.9  173.5   183.7  186.5  190.3  179.3
# 2022년 03분기  142.0  162.6  185.5  182.1  171.2   168.3  179.3  172.3  164.3
# 2022년 04분기  150.2  143.2  172.6  161.7  156.9   149.3  160.5  151.9  144.8
# 2023년 01분기  133.7  143.2  160.0  158.9  149.7   145.8  155.1  149.8  143.6
#
# ...

# %%
df_T.index.values
# Out:
# array(['2006년 01분기', '2006년 02분기', '2006년 03분기', '2006년 04분기',
#        '2007년 01분기', '2007년 02분기', '2007년 03분기', '2007년 04분기',
#        '2008년 01분기', '2008년 02분기', '2008년 03분기', '2008년 04분기',
#        '2009년 01분기', '2009년 02분기', '2009년 03분기', '2009년 04분기',
#        '2010년 01분기', '2010년 02분기', '2010년 03분기', '2010년 04분기',
#        '2011년 01분기', '2011년 02분기', '2011년 03분기', '2011년 04분기',
#        '2012년 01분기', '2012년 02분기', '2012년 03분기', '2012년 04분기',
#        '2013년 01분기', '2013년 02분기', '2013년 03분기', '2013년 04분기',
#        '2014년 01분기', '2014년 02분기', '2014년 03분기', '2014년 04분기',
#        '2015년 01분기', '2015년 02분기', '2015년 03분기', '2015년 04분기',
#        '2016년 01분기', '2016년 02분기', '2016년 03분기', '2016년 04분기',
#        '2017년 01분기', '2017년 02분기', '2017년 03분기', '2017년 04분기',
#        '2018년 01분기', '2018년 02분기', '2018년 03분기', '2018년 04분기',
#        '2019년 01분기', '2019년 02분기', '2019년 03분기', '2019년 04분기',
#        '2020년 01분기', '2020년 02분기', '2020년 03분기', '2020년 04분기',
# ...

# %%
df_T.columns.values
# Out:
# array(['서울 종로구', '서울 중구', '서울 용산구', '서울 성동구', '서울 광진구', '서울 동대문구',
#        '서울 중랑구', '서울 성북구', '서울 강북구', '서울 도봉구', '서울 노원구', '서울 은평구',
#        '서울 서대문구', '서울 마포구', '서울 양천구', '서울 강서구', '서울 구로구', '서울 금천구',
#        '서울 영등포구', '서울 동작구', '서울 관악구', '서울 서초구', '서울 강남구', '서울 송파구',
#        '서울 강동구', '부산 서구', '부산 동구', '부산 영도구', '부산 부산진구', '부산 동래구', '부산 남구',
#        '부산 북구', '부산 해운대구', '부산 사하구', '부산 금정구', '부산 연제구', '부산 수영구',
#        '부산 사상구', '부산 기장군', '대구 중구', '대구 동구', '대구 서구', '대구 남구', '대구 북구',
#        '대구 수성구', '대구 달서구', '대구 달성군', '인천 중구', '인천 동구', '인천 미추홀구',
#        '인천 연수구', '인천 남동구', '인천 부평구', '인천 계양구', '인천 서구', '광주 동구', '광주 서구',
#        '광주 남구', '광주 북구', '광주 광산구', '대전 동구', '대전 중구', '대전 서구', '대전 유성구',
#        '대전 대덕구', '울산 중구', '울산 남구', '울산 동구', '울산 북구', '울산 울주군', '경기 수원시',
#        '경기 수원시 장안구', '경기 수원시 권선구', '경기 수원시 팔달구', '경기 수원시 영통구', '경기 성남시',
#        '경기 성남시 수정구', '경기 성남시 중원구', '경기 성남시 분당구', '경기 의정부시', '경기 안양시',
# ...

# %%
len(df.columns[1:])
# Out:
# 69

# %%
#df.iloc[:1, 1:]
#df[0:1][:]
type(df[0:1:3])
# Out:
# pandas.core.frame.DataFrame

# %%
# %matplotlib inline
import matplotlib.pyplot as plt 
plt.rc('font', family='NanumGothic') # For Windows
df_T[["서울 종로구", '서울 용산구']].plot(legend=False)
plt.xticks(rotation=90)
plt.figure(figsize=(300,300))
plt.show()
